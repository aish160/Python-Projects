# %%
#Aishwarya Muttineni

# %%
# !pip install instafilter
# Out:
# ...
#      |████████████████████████████████| 266kB 13.6MB/s
# ...
#   Created wheel for instafilter: filename=instafilter-0.3.1-cp37-none-any.whl size=292567 sha256=54609f66dfa3aed259f58a5157efe60e725e4367c55f3f9ae47c7d7c4ded936e
#   Stored in directory: /root/.cache/pip/wheels/95/9b/c0/04cbd12c0bb5e7f41840e38f8cd2cdf503950b81e0f27dd47b
# Successfully built instafilter
# ...

# %%
image = cv2.imread("Aishu.jpg")
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=840x896 at 0x7FED40012590>
# -1

# %%
from instafilter import Instafilter
from google.colab.patches import cv2_imshow

model = Instafilter("Juno")
new_image = model("Aishu.jpg")

# To save the image, use cv2
import cv2
cv2.imwrite("modified_Aishu.jpg", new_image)
cv2_imshow(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=840x896 at 0x7FED4007E250>

# %%
from instafilter import Instafilter
from google.colab.patches import cv2_imshow

model = Instafilter("Lo-Fi")
new_image = model("Aishu.jpg")

# To save the image, use cv2
import cv2
cv2.imwrite("modified_Aishu.jpg", new_image)
cv2_imshow(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=840x896 at 0x7FED4007ED10>
